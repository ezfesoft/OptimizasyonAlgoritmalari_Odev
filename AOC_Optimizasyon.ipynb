# %%
import numpy as np
import sklearn.datasets as datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score
import random

# Karınca Kolonisi Algoritması için temel yapı
def karinca_kolonisi_algoritmasi(veri, k, max_iterasyon):
    num_samples = veri.shape[0]
    karinca_yolu = np.zeros((num_samples, k))
    feromon = np.ones((num_samples, k))
    en_iyi_cozum = None
    en_iyi_skora = -1

    for iterasyon in range(max_iterasyon):
        for i in range(num_samples):
            olasiliklar = feromon[i] / np.sum(feromon[i])
            secim = np.random.choice(range(k), p=olasiliklar)
            karinca_yolu[i, secim] = 1

        gruplar = np.argmax(karinca_yolu, axis=1)
        try:
          silhouette_skoru = silhouette_score(veri, gruplar)
          davies_bouldin_skoru = davies_bouldin_score(veri, gruplar)
          print(f"Silhouette Skoru: {silhouette_skoru}")
          print(f"Davies-Bouldin Skoru: {davies_bouldin_skoru}")
        except ValueError as e:
          print(f"Hata: {e}")
          print("Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.")


        if silhouette_skoru > en_iyi_skora:
            en_iyi_cozum = gruplar
            en_iyi_skora = silhouette_skoru

        feromon *= 0.9  # Feromon buharlaşması
        for i in range(num_samples):
            feromon[i, gruplar[i]] += 1 / num_samples

    return en_iyi_cozum, en_iyi_skora

# Lojistik Kaotik Haritası için temel yapı
def lojistik_kaotik_harita(baslangic, iterasyon_sayisi):
    x = baslangic
    kaotik_dizi = []
    for _ in range(iterasyon_sayisi):
        x = 4 * x * (1 - x)
        kaotik_dizi.append(x)
    return np.array(kaotik_dizi)

# Sklearn veri setlerini yükleme
datasetler = {
    "iris": datasets.load_iris().data,
    "wine": datasets.load_wine().data,
    "digits": datasets.load_digits().data,
    "breast_cancer": datasets.load_breast_cancer().data
}

# Veri ön işleme (normalize etme)
scaler = MinMaxScaler()
for isim, veri in datasetler.items():
    datasetler[isim] = scaler.fit_transform(veri)

# Parametreler
kume_sayisi = 3
maks_iterasyon = 100
kaotik_baslangic = random.uniform(0, 1)

# Tüm veri setleri için algoritmaları çalıştırma
sonuclar = {}
for isim, veri in datasetler.items():
    print(f"\nVeri seti: {isim}")

    # Karınca Kolonisi Algoritması
    kumeleme, skor = karinca_kolonisi_algoritmasi(veri, kume_sayisi, maks_iterasyon)
    print(f"Karınca Kolonisi Skoru: {skor}")

    # Lojistik Kaotik Harita
    kaotik_dizi = lojistik_kaotik_harita(kaotik_baslangic, veri.shape[0])
    print(f"Lojistik Kaotik Harita İlk 5 Değer: {kaotik_dizi[:5]}")

    sonuclar[isim] = {
        "karinca_skor": skor,
        "kaotik_dizi": kaotik_dizi
    }
# Out:
# Veri seti: iris
# Silhouette Skoru: -0.034008522281383964
# Davies-Bouldin Skoru: 24.174809936469817
# Silhouette Skoru: -0.06734497127082172
# Davies-Bouldin Skoru: 16.492550199100062
# Silhouette Skoru: -0.06306665471457126
# Davies-Bouldin Skoru: 21.522342510621485
# Silhouette Skoru: -0.2803496092178552
# Davies-Bouldin Skoru: 8.616378051880469
# Silhouette Skoru: -0.3029493459981643
# Davies-Bouldin Skoru: 7.060742361157026
# Silhouette Skoru: -0.3633897265629927
# Davies-Bouldin Skoru: 2.647259656443719
# Silhouette Skoru: -0.3892185401766891
# Davies-Bouldin Skoru: 2.247606463349325
# Silhouette Skoru: 0.05476487781141533
# Davies-Bouldin Skoru: 4.072578162835943
# Silhouette Skoru: 0.03556046778813195
# Davies-Bouldin Skoru: 2.797025229392596
# Silhouette Skoru: 0.06824488004623212
# Davies-Bouldin Skoru: 2.839120194995663
# Silhouette Skoru: 0.06824488004623212
# Davies-Bouldin Skoru: 2.839120194995663
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Karınca Kolonisi Skoru: 0.06824488004623212
# Lojistik Kaotik Harita İlk 5 Değer: [0.93262477 0.25134322 0.75267922 0.74461285 0.7606582 ]
#
# Veri seti: wine
# Silhouette Skoru: -0.020319849338627072
# Davies-Bouldin Skoru: 7.949282698265421
# Silhouette Skoru: -0.023954023189201964
# Davies-Bouldin Skoru: 12.669690559512423
# Silhouette Skoru: -0.041146649788160995
# Davies-Bouldin Skoru: 7.426329483998939
# Silhouette Skoru: -0.011898227256055856
# Davies-Bouldin Skoru: 20.47197246713749
# Silhouette Skoru: -0.004275628606620467
# Davies-Bouldin Skoru: 12.675361882731831
# Silhouette Skoru: 0.010819039201251773
# Davies-Bouldin Skoru: 18.322411552308356
# Silhouette Skoru: 0.01118591317045987
# Davies-Bouldin Skoru: 9.854407564593222
# Silhouette Skoru: 0.027559530534597025
# Davies-Bouldin Skoru: 6.046598685263248
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Silhouette Skoru: -0.04409743719819777
# Davies-Bouldin Skoru: 1.071876986250778
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Karınca Kolonisi Skoru: 0.027559530534597025
# Lojistik Kaotik Harita İlk 5 Değer: [0.93262477 0.25134322 0.75267922 0.74461285 0.7606582 ]
#
# Veri seti: digits
# Silhouette Skoru: -0.0030274464300968345
# Davies-Bouldin Skoru: 44.076044889067894
# Silhouette Skoru: -0.0033456235193595075
# Davies-Bouldin Skoru: 39.40304534036376
# Silhouette Skoru: -0.011999144317578278
# Davies-Bouldin Skoru: 26.912881575790703
# Silhouette Skoru: -0.018209319913091833
# Davies-Bouldin Skoru: 19.49653650966681
# Silhouette Skoru: -0.03262621754770894
# Davies-Bouldin Skoru: 20.03423215286911
# Silhouette Skoru: 0.0008507769815617966
# Davies-Bouldin Skoru: 31.828105700143723
# Silhouette Skoru: -0.003038232323210223
# Davies-Bouldin Skoru: 24.006853296574757
# Silhouette Skoru: 0.0015243571902648948
# Davies-Bouldin Skoru: 23.31824958992436
# Silhouette Skoru: 0.005369994298867975
# Davies-Bouldin Skoru: 24.525243260359495
# Silhouette Skoru: 0.012111646384938847
# Davies-Bouldin Skoru: 14.259311612444234
# Silhouette Skoru: 0.022839355248453826
# Davies-Bouldin Skoru: 11.254827981435785
# Silhouette Skoru: 0.011463685585102506
# Davies-Bouldin Skoru: 11.34677377867133
# Silhouette Skoru: 0.007442107915486897
# Davies-Bouldin Skoru: 4.72777856260008
# Silhouette Skoru: 0.0021534519655575447
# Davies-Bouldin Skoru: 2.450939360042766
# Silhouette Skoru: 0.0021534519655575447
# Davies-Bouldin Skoru: 2.450939360042766
# Silhouette Skoru: 0.0021534519655575447
# Davies-Bouldin Skoru: 2.450939360042766
# Silhouette Skoru: 0.004539448206495528
# Davies-Bouldin Skoru: 0.9520159942738455
# Silhouette Skoru: 0.004539448206495528
# Davies-Bouldin Skoru: 0.9520159942738455
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Karınca Kolonisi Skoru: 0.022839355248453826
# Lojistik Kaotik Harita İlk 5 Değer: [0.93262477 0.25134322 0.75267922 0.74461285 0.7606582 ]
#
# Veri seti: breast_cancer
# Silhouette Skoru: -0.01902550989611648
# Davies-Bouldin Skoru: 21.53658402069983
# Silhouette Skoru: -0.04153957338318766
# Davies-Bouldin Skoru: 20.510172371820957
# Silhouette Skoru: -0.04136662793605493
# Davies-Bouldin Skoru: 20.973039403529288
# Silhouette Skoru: -0.15218732513569125
# Davies-Bouldin Skoru: 14.085927771351457
# Silhouette Skoru: -0.0068161273990262755
# Davies-Bouldin Skoru: 19.20995493408839
# Silhouette Skoru: -0.022874514450436298
# Davies-Bouldin Skoru: 20.55898889996357
# Silhouette Skoru: -0.09051256151259225
# Davies-Bouldin Skoru: 7.505221596122168
# Silhouette Skoru: -0.10605082245087218
# Davies-Bouldin Skoru: 6.089078377612997
# Silhouette Skoru: -0.12751483237450847
# Davies-Bouldin Skoru: 4.14986897717862
# Silhouette Skoru: -0.09443867507564781
# Davies-Bouldin Skoru: 4.056796285676126
# Silhouette Skoru: -0.09004986035343739
# Davies-Bouldin Skoru: 4.535397162022268
# Silhouette Skoru: -0.16987827990389376
# Davies-Bouldin Skoru: 2.717648509145792
# Silhouette Skoru: -0.16987827990389376
# Davies-Bouldin Skoru: 2.717648509145792
# Silhouette Skoru: -0.17068334386730735
# Davies-Bouldin Skoru: 2.656549629108843
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.13364953713519362
# Davies-Bouldin Skoru: 2.3233572672058767
# Silhouette Skoru: -0.018404618408475498
# Davies-Bouldin Skoru: 0.921273633310992
# Silhouette Skoru: -0.018404618408475498
# Davies-Bouldin Skoru: 0.921273633310992
# Silhouette Skoru: -0.018404618408475498
# Davies-Bouldin Skoru: 0.921273633310992
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Hata: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# Silhouette veya Davies-Bouldin skorları yalnızca en az iki farklı küme olduğunda hesaplanabilir.
# Karınca Kolonisi Skoru: -0.0068161273990262755
# Lojistik Kaotik Harita İlk 5 Değer: [0.93262477 0.25134322 0.75267922 0.74461285 0.7606582 ]
